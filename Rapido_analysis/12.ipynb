# %%
import pandas as pd
df = pd.read_csv("rapido_july2025_data.csv")
display(df.head(5))
# Out:
#        Booking_ID Booking_Status  Booking_Value Customer_ID Driver_ID  \
# 0  RAP20250700001      Completed         170.39   CUST_2824    DR_902
# 1  RAP20250700002     Incomplete         131.04   CUST_1409    DR_915
# 2  RAP20250700003      Completed         242.19   CUST_5506    DR_938
# 3  RAP20250700004      Completed          78.18   CUST_5012    DR_213
# 4  RAP20250700005      Completed         159.33   CUST_4657    DR_783
#
#   Pickup_Location Drop_Location  Ride_Distance(km)  Ride_Time(min)  \
# 0            Pune         Delhi               2.74              42
# 1         Chennai     Hyderabad              22.15              20
# 2           Delhi     Bengaluru              11.95              46
# 3            Pune     Hyderabad               9.08              24
# 4         Chennai     Bengaluru              22.97              40
#
#          Date  ... Driver_Rating Canceled_Rides_by_Customer  \
# 0  2025-07-02  ...           4.3                          0
# ...

# %%
df['Drop_Location'].unique()
# Out:
# array(['Delhi', 'Hyderabad', 'Bengaluru', 'Pune', 'Chennai'], dtype=object)
